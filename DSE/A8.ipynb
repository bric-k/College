# %%
import numpy as py
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/sidbh/Documents/College/DSE/company_sales_data.csv')
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month_number  12 non-null     int64
#  1   facecream     12 non-null     int64
#  2   facewash      12 non-null     int64
#  3   toothpaste    12 non-null     int64
#  4   bathingsoap   12 non-null     int64
#  5   shampoo       12 non-null     int64
#  6   moisturizer   12 non-null     int64
#  7   total_units   12 non-null     int64
#  8   total_profit  12 non-null     int64
# dtypes: int64(9)
# memory usage: 996.0 bytes

# %%
df.shape
# Out:
# (12, 9)

# %%
df.describe()
# Out:
#        month_number    facecream     facewash   toothpaste   bathingsoap  \
# count     12.000000    12.000000    12.000000    12.000000     12.000000
# mean       6.500000  2873.333333  1542.916667  5825.833333   9500.833333
# std        3.605551   584.595172   316.733745  1242.032486   2348.095779
# min        1.000000  1990.000000  1120.000000  4550.000000   6100.000000
# 25%        3.750000  2460.000000  1305.000000  4862.500000   8015.000000
# 50%        6.500000  2830.000000  1527.500000  5530.000000   9090.000000
# 75%        9.250000  3435.000000  1765.000000  6400.000000  10045.000000
# max       12.000000  3700.000000  2100.000000  8300.000000  14400.000000
#
#            shampoo  moisturizer  total_units   total_profit
# count    12.000000    12.000000     12.00000      12.000000
# mean   2117.500000  1542.916667  26027.50000  260275.000000
# std     617.724931   316.733745   7014.36594   70143.659404
# min    1200.000000  1120.000000  18330.00000  183300.000000
# ...

# %%
y=df['total_profit'].tolist()
x=df['month_number'].tolist()

plt.plot(x,y, label= 'Month-wise Profit Data', color = "red")
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.xticks(x)
plt.title('Company profits per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.legend()
plt.show()

# %%
plt.plot(x,y, label= 'Profit Data of last year', color = 'g', marker='*', markerfacecolor = 'k', linestyle = '--', linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.xticks(x)
plt.title('Company sales data of last year')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.legend()
plt.show()

# %%
profitlist=df['total_profit'].tolist()
labels = ['low', 'average', 'good', 'best']
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(profitlist, profit_range, label = 'Profit Data', color = "blue")
plt.xlabel('Profit range in Dollars')
plt.ylabel('Actual profit in Dollars')
plt.xticks(profit_range)
plt.title('Profit Data')
plt.legend(loc = 'upper left')
plt.show()

# %%
labels = ['FaceCream', 'FaceWash', 'Toothpaste', 'Bathing Soap', 'Shampoo', 'Moisturiser']
salesdata = [df['facecream'].sum(), df['facewash'].sum(), df['toothpaste'].sum(), df['bathingsoap'].sum(), df['shampoo'].sum(), df['moisturizer']]
plt.axis("equal")
plt.axis(salesdata, explode = (0,0,0.3,0,0,0), labels=labels, autopct = '% d %%', radius = 1.5, shadow = True)
plt.legend(loc = 'upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 salesdata = [df['facecream'].sum(), df['facewash'].sum(), df['toothpaste'].sum(), df['bathingsoap'].sum(), df['shampoo'].sum(), df['moisturizer']]
#       3 plt.axis("equal")
# ----> 4 plt.axis(salesdata, explode = (0,0,0.3,0,0,0), labels=labels, autopct = '% d %%', radius = 1.5, shadow = True)
#       5 plt.legend(loc = 'upper right')
#       6 plt.show()
#
# File c:\Python312\Lib\site-packages\matplotlib\pyplot.py:2713, in axis(arg, emit, **kwargs)
#    2705 @_copy_docstring_and_deprecators(Axes.axis)
#    2706 def axis(
#    2707     arg: tuple[float, float, float, float] | bool | str | None = None,
#    (...)
#    2711     **kwargs,
#    2712 ) -> tuple[float, float, float, float]:
# -> 2713     return gca().axis(arg, emit=emit, **kwargs)
#
# ...
